# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
df = pd.read_csv('Linear.csv')
df
# Out:
#          Height      Weight
# 0     73.847017  241.893563
# 1     68.781904  162.310473
# 2     74.110105  212.740856
# 3     71.730978  220.042470
# 4     69.881796  206.349801
# ...         ...         ...
# 3993  66.648475  172.317509
# 3994  68.171875  194.990195
# 3995  73.339168  203.064742
# 3996  61.470369  128.724050
# 3997  69.012299  177.057807
#
# [3998 rows x 2 columns]

# %%
def estimate_coef(x, y):
    n = np.size(x)
    m_x = np.mean(x)
    m_y = np.mean(y)
    SS_xy = n*np.sum(y*x) -(np.sum(x)*np.sum(y))
    SS_xx = n*np.sum(x*x) - (np.sum(x)*np.sum(x)) 
    m = SS_xy / SS_xx
    c = (np.sum(y) - m*np.sum(x))/n
    return (m,c)
def plot_regression_line(x, y, m, c):
    plt.scatter(x, y, color = "m", marker = "o", s = 30)
    y_pred = (m*x)+c
    plt.plot(x, y_pred, color = "g") 
    plt.xlabel('Height')
    plt.ylabel('Weight')
    plt.title('Simple Linear Regression')
    plt.show()
if __name__ == "__main__":
    x = df['Height']
    y = df['Weight']
    m, c = estimate_coef(x, y)
    print("Estimated coefficients: Slope =", m, " Intercept =", c)
    plot_regression_line(x, y, m, c)
print("Roll Num: CB.SC.I5DAS21049")
print("Name: Pratiksha Cauvery K P")
# Out:
# Estimated coefficients: Slope = 3.4308199361563734  Intercept = -49.57541068752182
# Roll Num: CB.SC.I5DAS21049
# Name: Pratiksha Cauvery K P
